# %% [markdown]
# # Урок 5. Рекуррентные нейронные сети
#
# ## Практическое задание
#
# <ol>
#     <li>Попробуйте изменить параметры нейронной сети работающей с датасетом imdb либо нейронной сети работающей airline-passengers(она прилагается вместе с датасетом к уроку в виде отдельного скрипта) так, чтобы улучшить ее точность. Приложите анализ.</li>
#     <li>Попробуйте изменить параметры нейронной сети генерирующий текст таким образом, чтобы добиться генерации как можно более осмысленного текста. Пришлите лучший получившейся у вас текст и опишите, что вы предприняли, чтобы его получить. Можно использовать текст другого прозведения.</li>
#     <li>* Попробуйте на numpy реализовать нейронную сеть архитектуры LSTM</li>
#     <li>* Предложите свои варианты решения проблемы исчезающего градиента в RNN</li>
# </ol>

# %% [markdown]
# ## Задание 1. Решение:

# %%
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import Dropout, LSTM, ConvLSTM1D
from keras.datasets import imdb
from keras.utils import pad_sequences
from random import shuffle, choice
from tools import paralell_execution, ar_split_eq_cpu

max_features = 10000

# обрезание текстов после данного количества слов (среди top max_features наиболее используемые слова)
maxlen = 100
batch_size = 128 # увеличьте значение для ускорения обучения
activations = ['relu', 'LeakyReLU', 'elu']

# комбинации параметров нейросети 
best_acc = 0 # точность лучшей модели
best_params = {} # параметры лучшей модели
best_model = None # лучшая модель
params = []
for genf in [LSTM]: # LSTM, ConvLSTM1D
    for optimizer in ['SGD', 'adam']: # 'SGD','RMSProp','adam','NAdam'
        for loops in [1, 2]:
            for dense_size in [32, 64]:
                for epochs in [10]:
                    for dropout in [True, False]:
                        params.append({
                                           'genf': genf, 
                                           'optimizer': optimizer, 
                                           'dense_size': dense_size, 
                                           'epochs': epochs, 
                                           'dropout': dropout, 
                                           'activation': choice(activations), 
                                           'loops': loops, 
                                      })

shuffle(params)

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)
x_train = pad_sequences(x_train, maxlen=maxlen)
x_test = pad_sequences(x_test, maxlen=maxlen)

print(f'Всего комбинаций параметров: {len(params)}')
# Out:
# Всего комбинаций параметров: 16

# %%
def train(params):
    p = params['PARAMS']
    param = p['param']
    x_train = p['x_train']
    y_train = p['y_train']
    x_test = p['x_test']
    y_test = p['y_test']
    batch_size = p['batch_size']
    max_features = p['max_features']
    
    # print('Построение модели...')
    model = Sequential()
    model.add(Embedding(max_features, 128))
    model.add(param['genf'](128, dropout=0.4, recurrent_dropout=0.4))
    for i in range(param['loops']):
        model.add(Dense(param['dense_size'], activation=param['activation']))
        if param['dropout']:
            model.add(Dropout(0.4))
    model.add(Dense(1, activation='sigmoid'))
    
    # стоит попробовать использовать другие оптимайзер и другие конфигурации оптимайзеров
    model.compile(loss='binary_crossentropy',
                optimizer=param['optimizer'], # при использовании этого оптимайзера модель показывает наилучшие результаты.
                metrics=['accuracy'])
    
    # print('Процесс обучения...')
    model.fit(x_train, y_train,
                batch_size=batch_size,
                epochs=10, # увеличьте при необходимости
                validation_data=(x_test, y_test),
                verbose=0)
    
    score, acc = model.evaluate(x_test, 
                                y_test, 
                                batch_size=batch_size,
                                verbose=0)
    
    return {'best_acc': acc,
            'best_params': param,
            'model': model}


args_parallel = []
for param in ar_split_eq_cpu(params):
    args_parallel.append({
        'PARAMS':{
            'param': param[0],
            'x_train': x_train,
            'y_train': y_train,
            'x_test': x_test,
            'y_test': y_test,
            'batch_size': batch_size,
            'max_features': max_features,
        }
    })

# запускаем процесс параллельных вычислений
res = paralell_execution(func=train,
                         arg=args_parallel,
                         method='multiprocessing')

for row in res: # объединяем результаты со всех ядер
    if row['best_acc'] > best_acc:
        best_acc = row['best_acc']
        best_params = row['best_params']
        best_model = row['model']

print(f'Лучшая точность: {best_acc} при параметрах {best_params}')
# Out:
# Лучшая точность: 0.8278800249099731 при параметрах {'genf': <class 'keras.layers.rnn.lstm.LSTM'>, 'optimizer': 'adam', 'dense_size': 64, 'epochs': 10, 'dropout': False, 'activation': 'relu', 'loops': 2}

# %%
# Структура лучшей модели
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 128)         1280000
#
#  lstm (LSTM)                 (None, 128)               131584
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 1,424,065
# Trainable params: 1,424,065
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Ответ
#
# Лучшая точность:
#
# 0.8278800249099731
#
# При параметрах {'genf': <class 'keras.layers.rnn.lstm.LSTM'>, 'optimizer': 'adam', 'dense_size': 64, 'epochs': 10, 'dropout': False, 'activation': 'relu', 'loops': 2}

# %% [markdown]
# ## Задание 2. Решение:

# %%
# alice_in_wonderland пример из урока

from random import shuffle, choice
from tools import paralell_execution, ar_split_eq_cpu
import numpy as np
import os
# Загрузка keras перенесена внутрь процесса. Иначе не работает при многоядерности: https://stackoverflow.com/questions/42504669/keras-tensorflow-and-multiprocessing-in-python
# from keras.layers import Dense, Activation
# from keras.layers import SimpleRNN, LSTM, GRU
# from keras.models import Sequential

# построчное чтение из примера с текстом 
with open("alice_in_wonderland.txt", 'rb') as _in:
    lines = []
    for line in _in:
        line = line.strip().lower().decode("ascii", "ignore")
        if len(line) == 0:
            continue
        lines.append(line)
text = " ".join(lines)
chars = set([c for c in text])
nb_chars = len(chars)

# создание индекса символов и reverse mapping чтобы передвигаться между значениями numerical
# ID and a specific character. The numerical ID will correspond to a column
# ID и определенный символ. Numerical ID будет соответсвовать колонке
# число при использовании one-hot кодировки для представление входов символов
char2index = {c: i for i, c in enumerate(chars)}
index2char = {i: c for i, c in enumerate(chars)}

# для удобства выберете фиксированную длину последовательность 10 символов 
SEQLEN, STEP = 10, 1
input_chars, label_chars = [], []

# конвертация data в серии разных SEQLEN-length субпоследовательностей
for i in range(0, len(text) - SEQLEN, STEP):
    input_chars.append(text[i: i + SEQLEN])
    label_chars.append(text[i + SEQLEN])


# Вычисление one-hot encoding входных последовательностей X и следующего символа (the label) y

X = np.zeros((len(input_chars), SEQLEN, nb_chars), dtype=bool)
y = np.zeros((len(input_chars), nb_chars), dtype=bool)
for i, input_char in enumerate(input_chars):
    for j, ch in enumerate(input_char):
        X[i, j, char2index[ch]] = 1
    y[i, char2index[label_chars[i]]] = 1


# комбинации параметров нейросети 
best_acc = 0 # точность лучшей модели
best_params = {} # параметры лучшей модели
best_model = None # лучшая модель
params = []
for NUM_ITERATIONS in [15, 25]:
    for HIDDEN_SIZE in [64, 128]:
        for BATCH_SIZE in [64, 128]:
            for NUM_EPOCHS_PER_ITERATION in [1, 2]:
                for NUM_PREDS_PER_EPOCH in [100, 200]:
                    for algo in ['GRU', 'LSTM', 'SimpleRNN']: # LSTM, SimpleRNN
                        params.append({
                                           'NUM_ITERATIONS': NUM_ITERATIONS,
                                           'HIDDEN_SIZE': HIDDEN_SIZE,
                                           'BATCH_SIZE': BATCH_SIZE,
                                           'NUM_EPOCHS_PER_ITERATION': NUM_EPOCHS_PER_ITERATION,
                                           'NUM_PREDS_PER_EPOCH': NUM_PREDS_PER_EPOCH,
                                           'algo': algo,
                                      })
shuffle(params)
print(f'Всего комбинаций параметров: {len(params)}')
# Out:
# Всего комбинаций параметров: 96

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
def train(params):
    # Загрузка keras перенесена внутрь процесса. Иначе не работает при многоядерности: https://stackoverflow.com/questions/42504669/keras-tensorflow-and-multiprocessing-in-python
    os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
    from keras.layers import Dense, Activation
    from keras.layers import SimpleRNN, LSTM, GRU
    from keras.models import Sequential
    
    p = params['PARAMS']
    param = p['param']
    X = p['X']
    y = p['y']
    SEQLEN = p['SEQLEN']
    STEP = p['STEP']
    text = p['text']
    chars = p['chars']
    nb_chars = p['nb_chars']
    input_chars = p['input_chars']
    label_chars = p['label_chars']
    char2index = p['char2index']
    index2char = p['index2char']
    
    # установка ряда метапамертров  для нейронной сети и процесса тренировки
    algo = param['algo'] 
    
    if algo == 'GRU':
        algo = GRU
    if algo == 'LSTM':
        algo = LSTM
    if algo == 'SimpleRNN':
        algo = SimpleRNN
        
    BATCH_SIZE = param['BATCH_SIZE']
    HIDDEN_SIZE = param['HIDDEN_SIZE']
    NUM_ITERATIONS = param['NUM_ITERATIONS'] # 25 должно быть достаточно
    NUM_EPOCHS_PER_ITERATION = param['NUM_EPOCHS_PER_ITERATION']
    NUM_PREDS_PER_EPOCH = param['NUM_PREDS_PER_EPOCH']
    
    # Создание очень простой рекуррентной нейронной сети. В ней будет один 
    # реккурентный закодированный входной слой. За ним последует полносвязный 
    # слой связанный с набором возможных следующих символов, которые 
    # конвертированы в вероятностные результаты через стандартную softmax 
    # активацию с multi-class cross-encoding loss функцию ссылающуются на 
    # предсказание one-hot encoding лейбл символа
    
    model = Sequential()
    model.add(
        algo(
            HIDDEN_SIZE,
            return_sequences=False,
            input_shape=(SEQLEN, nb_chars),
            unroll=True
        )
    )
    model.add(Dense(nb_chars))
    model.add(Activation("softmax"))
    model.compile(loss="categorical_crossentropy", optimizer="rmsprop")
    
    # выполнение серий тренировочных и демонстрационных итераций 
    for iteration in range(NUM_ITERATIONS):
        model.fit(X, y, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION, verbose=0)
    
    y_pred_seed = ''
    y_pred_final = ''
    # Select a random example input sequence.
    test_idx = np.random.randint(len(input_chars))
    test_chars = input_chars[test_idx]

    # для числа шагов предсказаний использование текущей тренируемой модели 
    # конструирование one-hot encoding для тестирования input и добавление предсказания.
    # print("Генерация из посева: %s" % (test_chars))
    # print(test_chars, end="")
    y_pred_seed = test_chars
    
    for i in range(NUM_PREDS_PER_EPOCH):

        # здесь one-hot encoding.
        X_test = np.zeros((1, SEQLEN, nb_chars))
        for j, ch in enumerate(test_chars):
            X_test[0, j, char2index[ch]] = 1

        # осуществление предсказания с помощью текущей модели.
        pred = model.predict(X_test, verbose=0)[0]
        y_pred = index2char[np.argmax(pred)]

        # вывод предсказания добавленного к тестовому примеру 
        # print(y_pred, end="")
        y_pred_final += y_pred

        # инкрементация тестового примера содержащего предсказание
        test_chars = test_chars[1:] + y_pred

    return {'phrase': f'Фраза из слов ({y_pred_seed}): {y_pred_final}',
            'param': param,
            'model': model}


args_parallel = []
for param in ar_split_eq_cpu(params):
    args_parallel.append({
        'PARAMS':{
            'param': param[0],
            'X': X,
            'y': y,
            'SEQLEN': SEQLEN,
            'STEP': STEP,
            'text': text,
            'chars': chars,
            'nb_chars': nb_chars,
            'input_chars': input_chars,
            'label_chars': label_chars,
            'char2index': char2index,
            'index2char': index2char,
        }
    })

# запускаем процесс параллельных вычислений
res = paralell_execution(func=train,
                         arg=args_parallel,
                         method='multiprocessing')

for row in res: # объединяем результаты со всех ядер
    phrase = row['phrase']
    param = row['param']
    print(f'Параметры: {param}')
    print(f'{phrase}')
# Out:
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'LSTM'}
# Фраза из слов ( work to p): roject gutenberg literary archive foundation and distributing project gutenberg literary archive foundation and distributing project gutenberg literary archive foundation and distributing project gute
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): urstented the door and she had as she had as she had as she had as she had as she had as she had as
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): roved the mouse was the mouse was the mouse was the mouse was the mouse was the mouse was the mouse
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): lease to her a the shall say of the mock turtle said the gryphon at the mock turtle said the gryphon
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): lease the door she was she cat she was the door she was she cat she was the door she was she cat she
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'LSTM'}
# Фраза из слов ( work to p): rovide a fucorres it a lory to change the sumple and donations to the part of this agreement for her
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic work to any a growing the mock turtle she had the mock turtle she had the mock turtle she had the mock turtle she had the mock turtle she had the mock turtle she had the
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'GRU'}
# Фраза из слов ( work to p): roject gutenberg literary archive foundation and did its answered her head to sen they all crowded round her hands of bread-there was eyes was the dormouse in the same thing as i somether the project
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'LSTM'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic works in a little shrilk was the work in the mock turtle went on the
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'LSTM'}
# Фраза из слов ( work to p): erter the project gutenberg-tm electronic works in a little the project gutenberg-tm electronic work
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): ershen in a looked the work your was the project gutenberg-tm elace a low said the dormouse the was
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): rovided up and she was no a little shrefted out a work of the table, said the mock turtle some of the table, said the mock turtle some of the table, said the mock turtle some of the table, said the mo
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): ersent the the said the dormouse the cat of the gryphon and the more the said the dormouse the cat of the gryphon and the more the said the dormouse the cat of the gryphon and the more the said the do
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'LSTM'}
# Фраза из слов ( work to p): rovide a comply im a little bill, said the dormouse should be a mouse to the court, and the dormouse
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'LSTM'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic work and the hatter was a little began she was a little began she was a little began she was a little began she was a little began she was a little began she was a littl
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic works on the gryphon was the gryphon was the gryphon was the gryphon
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'GRU'}
# Фраза из слов ( work to p): rovess to see the caterpillar the caterpillar the caterpillar the caterpillar the caterpillar the caterpillar the caterpillar the caterpillar the caterpillar the caterpillar the caterpillar the caterp
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'LSTM'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic works in a long to the dormouse of the words and the dormouse of the words and the dormouse of the words and the dormouse of the words and the dormouse of the words and
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'GRU'}
# Фраза из слов ( work to p): rovide a card of the project gutenberg-tm electronic work in a little began to the project gutenberg
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'LSTM'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic work of the cateres in the said to the cant to see the dormouse in a
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'GRU'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic works and she was the duchess and she was the duchess and she was the
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'LSTM'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic work is to be talking a patter to say the pigeon about it made out the stupp this again, and as it see it to say the pigeon about it made out the stupp this again, and a
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'LSTM'}
# Фраза из слов ( work to p): roject gutenberg-tm works and the trees under the teams with the trematies, you know. what are you c
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'GRU'}
# Фраза из слов ( work to p): roved an indations cones eyes and she had not any project gutenberg-tm conternty electronic works in a project gutenberg-tm conternty electronic works in a project gutenberg-tm conternty electronic wo
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'GRU'}
# Фраза из слов ( work to p): erson of the project gutenberg-tm electronic works the door of the seemed to see it was the dormouse the door of the seemed to see it was the dormouse the door of the seemed to see it was the dormouse
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'GRU'}
# Фраза из слов ( work to p): roject gutenberg-tm electronically the rabbit shoulder what i dont know the first the caterpillar some to alice to herself, and the mouse doesnt matter what i dont know the first the caterpillar some
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'LSTM'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic works when the project gutenberg-tm electronic works when the project gutenberg-tm electronic works when the project gutenberg-tm electronic works when the project guten
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'GRU'}
# Фраза из слов ( work to p): roject gutenberg-tm license the dormouse some of the same the poor little had all the thought the dormouse some of the same the poor little had all the thought the dormouse some of the same the poor l
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'GRU'}
# Фраза из слов ( work to p): rovided to think that they were like the little gor to do that in an offended tone, and the little gor to do that in an offended tone, and the little gor to do that in an offended tone, and the little
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic works of the should the rabbit states of the should the rabbit states
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): erson and the mock turtle with a little she had not at the project gutenberg-tm license them with a
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'LSTM'}
# Фраза из слов ( work to p): lease it was the duchess the dormouse the dormouse the dormouse the dormouse the dormouse the dormou
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'GRU'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic works in the march hare. the mock turtle in any lobsthing that the mo
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'LSTM'}
# Фраза из слов ( work to p): roject gutenberg literary archive foundation alice asked. the mock turtle seen the mouse to the proj
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'GRU'}
# Фраза из слов ( work to p): erint and the caterpillar she was a little said the door alice was the caterpillar she was a little said the door alice was the caterpillar she was a little said the door alice was the caterpillar she
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'GRU'}
# Фраза из слов ( work to p): rovided to you have be a little before a long mine, said alice. why, she was about her and the some
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic works of the court be the little got to the march hare of the court be the little got to the march hare of the court be the little got to the march hare of the court be
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'LSTM'}
# Фраза из слов ( work to p): roject gutenberg-tm license and a shrilkes of life! he had came upotling alice as he spoke, and the sort, said the mock turtle in her hand only a shreen stard another seamed to say alice as he spoke,
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic works in a mouse the white rabbit hasterself all the end of the same
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): rown the project gutenberg was and the project gutenberg was and the project gutenberg was and the project gutenberg was and the project gutenberg was and the project gutenberg was and the project gut
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'GRU'}
# Фраза из слов ( work to p): roved and she had not the gryphon and the gryphon and the gryphon and the gryphon and the gryphon an
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'GRU'}
# Фраза из слов ( work to p): erton a little began in the work in the court a little began in the work in the court a little began
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): roviden of the was the works a dort of the was the works a dort of the was the works a dort of the w
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'GRU'}
# Фраза из слов ( work to p): rovided the project gutenberg-tm electronic works of the thing it was the caterpillar conting the pr
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): reself the works and dont set the part as the dormouse do to have a long the sentence of the sort of
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'GRU'}
# Фраза из слов ( work to p): roject gutenberg litely and the trint of the project gutenberg litely and the trint of the project g
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'LSTM'}
# Фраза из слов ( work to p): rovide a little shriek of the say you do not at once without a serely, said the mock turtle to herse
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'LSTM'}
# Фраза из слов ( work to p): lay croquet. you should be a little sisters, and what a child! i would you think you could say the morning down the caterpillar. i would the shall think of the caterpillar. i would the shall think of
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'GRU'}
# Фраза из слов ( work to p): rovide a little before she had not look at the three gardeners were saying to herself to say in a lo
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): ersoly the mock turtle she had not the mort of the three she was not the mort of the three she was not the mort of the three she was not the mort of the three she was not the mort of the three she was
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): roject gutenberg-tm works of the white rabbit a court of the gryphon. which way it was so she could
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'GRU'}
# Фраза из слов ( work to p): rovide a read reectine alice did not like to be soupted in the door a little beginsing what late if
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'GRU'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic works and said to herself, and she was not at the project gutenberg-t
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'LSTM'}
# Фраза из слов ( work to p): roject gutenberg literary archive foundation and consider, as its a free, alace could not tell me no then in the world boon of the court, and then the right have been a red rose, the gryphon went on a
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'LSTM'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic works and the caterpillar was the caterpillar was the caterpillar was the caterpillar was the caterpillar was the caterpillar was the caterpillar was the caterpillar was
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'GRU'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic works in the door of the words and sharps all that it was the white rabbit was a little statter were then the mock turtle with the same thing the mock turtle with the sa
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'GRU'}
# Фраза из слов ( work to p): atce any of every now and then the dormouse into the party a little shail replied that the project g
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'GRU'}
# Фраза из слов ( work to p): roject gutenberg-tm works and the project gutenberg-tm works and the project gutenberg-tm works and
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'LSTM'}
# Фраза из слов ( work to p): roved alice, and she said to herself, and she said to herself, and she said to herself, and she said
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'GRU'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic work and the mock turtle seer the mock turtle seer the mock turtle seer the mock turtle seer the mock turtle seer the mock turtle seer the mock turtle seer the mock turt
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'LSTM'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic works of the same the mock turtle said the gryphon and she was the mo
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): roject gutenberg-tm like the morter the king the mock turtle she was the morter the king the mock turtle she was the morter the king the mock turtle she was the morter the king the mock turtle she was
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): reash how the hatter with the gardeners as the gryphon was the same the poor alice the poor alice the poor alice the poor alice the poor alice the poor alice the poor alice the poor alice the poor ali
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic work and she was a little so the more the fort the found the same the found the same the found the same the found the same the found the same the found the same the foun
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'LSTM'}
# Фраза из слов ( work to p): roject gutenberg-tm a marter the was she was the was she was the was she was the was she was the was she was the was she was the was she was the was she was the was she was the was she was the was she
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): ered the maden a little said the down the was a little said the down the was a little said the down
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'LSTM'}
# Фраза из слов ( work to p): rovide a little began to be any distlamed the pigeon the work of the shre such a little began to be
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'GRU'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic works to the dormouse to do a little sate of the work in the project gutenberg-tm electronic works to the dormouse to do a little sate of the work in the project gutenbe
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'GRU'}
# Фраза из слов ( work to p): roved the mouse did not like the things and she said the mock turtle said, and the mouse did not like the things and she said the mock turtle said, and the mouse did not like the things and she said t
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'LSTM'}
# Фраза из слов ( work to p): roved one of the song of the poor little thing to her electronic works in the soldiers or distribute
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): leased a said the could to the could to the could to the could to the could to the could to the could to the could to the could to the could to the could to the could to the could to the could to the
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): roject gutenberg-tm the the said the caterpillar she was the cat of the cat of the cat of the cat of
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic works the mock turtle was the mock turtle was the mock turtle was the mock turtle was the mock turtle was the mock turtle was the mock turtle was the mock turtle was the
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'GRU'}
# Фраза из слов ( work to p): rovide a realfuble, said alice, who was getting so much no resticed my edgea-- its rather fullought
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic works and a little she was a little she was a little she was a little
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'GRU'}
# Фраза из слов ( work to p): ersons and the mores and the mores and the mores and the mores and the mores and the mores and the mores and the mores and the mores and the mores and the mores and the mores and the mores and the mor
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'LSTM'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic works that she was a little good all the time the project gutenberg-t
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'GRU'}
# Фраза из слов ( work to p): rovide a come beand on the shook the could see it was a little shrieks of them better the mouse to again, the mock turtle was the rabbit was silence to learn it watched the mouse to again, the mock tu
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): rost the read and dont se andort the caterpillar down the read and dont se andort the caterpillar down the read and dont se andort the caterpillar down the read and dont se andort the caterpillar down
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'GRU'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic works to the three got to the three got to the three got to the three
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): lease of the soments project gutenberg-tm to she said the king the project gutenberg-tm to she said the king the project gutenberg-tm to she said the king the project gutenberg-tm to she said the king
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'GRU'}
# Фраза из слов ( work to p): roject gutenberg-tm license to do any then alice dody to see the cat remember the tree. i think it was a treacle-- the cat remember the tree. i think it was a treacle-- the cat remember the tree. i th
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'LSTM'}
# Фраза из слов ( work to p): rotect the queen should all the time he had misule tone, the duchess said to the knave of hearts, ca
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'LSTM'}
# Фраза из слов ( work to p): rovide a strapged and the trial of the court, and she was no herself that the rabbit had comply with the terms of this agreement that it was a little sirection in the sime in the right will you do you
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'LSTM'}
# Фраза из слов ( work to p): ertion and the caterpillar was a little some the cat her seated to the rabbit was the dormouse in a little some the cat her seated to the rabbit was the dormouse in a little some the cat her seated to
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'LSTM'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic works of the works of the works of the works of the works of the works of the works of the works of the works of the works of the works of the works of the works of the
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic work to see he was so one of the sounded to herself that she was going to herself that she was going to herself that she was going to herself that she was going to herse
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'LSTM'}
# Фраза из слов ( work to p): erpost and she was a little she was a little she was a little she was a little she was a little she
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'LSTM'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic works in the caterpillar the direction of the song of the seap to a treally all the things to see it was a little begin to the cat said the dormouse should be a little b
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'GRU'}
# Фраза из слов ( work to p): rovide to the white rabbit with the white rabbit with the white rabbit with the white rabbit with the white rabbit with the white rabbit with the white rabbit with the white rabbit with the white rabb
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'LSTM'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic works the mouse the caterpillar the mouse the caterpillar the mouse the caterpillar the mouse the caterpillar the mouse the caterpillar the mouse the caterpillar the mou
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 128, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'LSTM'}
# Фраза из слов ( work to p): roject gutenberg-tm electronic work is come serman to be a little shriek of the song, and she sat down and sat down and sat down and sat down and sat down and sat down and sat down and sat down and sa
# Параметры: {'NUM_ITERATIONS': 15, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 1, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): erself in the project gutenberg-tm the project gutenberg-tm the project gutenberg-tm the project gut
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 64, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 100, 'algo': 'GRU'}
# Фраза из слов ( work to p): lease in a little silence, and the mock turtle said to herself, and the mock turtle said to herself,
# Параметры: {'NUM_ITERATIONS': 25, 'HIDDEN_SIZE': 64, 'BATCH_SIZE': 128, 'NUM_EPOCHS_PER_ITERATION': 2, 'NUM_PREDS_PER_EPOCH': 200, 'algo': 'SimpleRNN'}
# Фраза из слов ( work to p): ersiage it was in the toot the toot the toot the toot the toot the toot the toot the toot the toot the toot the toot the toot the toot the toot the toot the toot the toot the toot the toot the toot th
